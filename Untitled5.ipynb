# %% [markdown]
# <a href="https://colab.research.google.com/github/jpsicilia/spotify_analysis/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importar librerias a utilizar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# cargar el data set

# %%
df=pd.read_csv('songs.csv')

# %% [markdown]
# eliminar duplicados

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated(subset=["artist", "song"]).sum()
# Ordenar por popularidad de mayor a menor y quedarte con la primera fila (más popular) por artista + canción
df=df.sort_values(by="popularity", ascending=False).drop_duplicates(subset=["artist", "song"], keep="first")
df.duplicated(subset=["artist", "song"]).sum()
df = df.reset_index(drop=True)

# %% [markdown]
# ### ¿Qué artistas generan más “engagement” (popularidad ponderada por cantidad de canciones)?
#
# Este análisis busca identificar a los artistas que no solo tienen canciones populares, sino que además mantienen esa popularidad de forma consistente a lo largo de múltiples temas.
# Para ello, usamos una métrica que pondera la popularidad media por la desviación estándar y la ajusta por la cantidad de canciones (`pop_ponderada = mean / std * log(n)`).
# Esto permite **penalizar artistas con pocas canciones** (y un solo éxito viral) y **valorar más a quienes sostienen un alto engagement con volumen**.
#
# La métrica resultante destaca a artistas con trayectoria sólida y consistencia en su rendimiento musical.

# %%
def score(series):
    return series.mean()/series.std()

def score_log(series):
    return (series.mean()/series.std())*np.log(len(series))

# %%
groupby_artist=df.groupby("artist").agg({"popularity": ["sum", "mean"]})
groupby_artist.columns=["popularity_sum", "popularity_mean"]
groupby_artist.sort_values(by="popularity_sum", ascending=False, inplace=True)
groupby_artist.head(10)
# Out:
#                 popularity_sum  popularity_mean
# artist
# Rihanna                   1662        72.260870
# Eminem                    1471        73.550000
# Drake                     1424        67.809524
# Calvin Harris             1356        67.800000
# Britney Spears            1198        63.052632
# David Guetta              1185        65.833333
# Katy Perry                1033        64.562500
# Beyoncé                   1030        64.375000
# Chris Brown               1012        63.250000
# Kanye West                 983        61.437500

# %% [markdown]
# Graficar artistas con mas engagement

# %%
groupby_artist.head(10).plot(
    y="popularity_mean",
    kind="bar",
    figsize=(10, 6),
    legend=False,
    color='skyblue'
)

plt.title("Engagement de cada artista")
plt.ylabel("Popularidad media")
plt.xlabel("Artista")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Géneros “premium”: popularidad vs volumen

# %%
df.head()
df['genre'] = df['genre'].replace('set()', 'desconocido')

# %%
# Separar, limpiar, ordenar y volver a unir
df['genre_clean'] = (
    df['genre']
    .str.split(',')
    .apply(lambda x: ', '.join(sorted([i.strip().lower() for i in x])))
)

# %%
# Agrupar por combinaciones de géneros
genero_stats = (
    df.groupby('genre_clean')['popularity']
      .agg(['count', 'mean'])
      .rename(columns={'count': 'num_canciones', 'mean': 'popularidad_media'})
      .reset_index()
)

# Calcular popularidad ponderada (por cantidad de canciones)
genero_stats['popularidad_ponderada'] = genero_stats['popularidad_media'] * np.log1p(genero_stats['num_canciones'])

# Ordenar para ver los más "fuertes"
genero_stats = genero_stats.sort_values(by='popularidad_ponderada', ascending=False)

# %%
genero_stats.head(10)
# Out:
#                        genre_clean  num_canciones  popularidad_media  \
# 34                    hip hop, pop            265          64.086792
# 44                             pop            411          59.128954
# 35               hip hop, pop, r&b            234          59.512821
# 31                         hip hop            120          64.241667
# 45                        pop, r&b            170          57.911765
# 15           dance/electronic, pop            213          53.741784
# 50                            rock             57          66.754386
# 46                       pop, rock             65          62.676923
# 12  dance/electronic, hip hop, pop             75          59.546667
# 43                     metal, rock             36          70.527778
#
#     popularidad_ponderada
# 34             357.828369
# 44             356.016811
# 35             324.915333
# 31             308.089578
# 45             297.762810
# 15             288.377124
# 50             271.052380
# 46             262.594668
# 12             257.880735
# 43             254.670016

# %%
top10 = genero_stats.head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top10, x='popularidad_ponderada', y='genre_clean', palette='viridis')
plt.title("Top 10 combinaciones de géneros más populares (ponderadas por volumen)")
plt.xlabel("Popularidad ponderada")
plt.ylabel("Combinación de géneros")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-288-2017e2e43e3d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top10, x='popularidad_ponderada', y='genre_clean', palette='viridis')

# %% [markdown]
# Explícitas vs. no explícitas: ¿impacto en popularidad?

# %%
groupby_explit=df.groupby("explicit").agg(
    song_cont=("song","count"),
    avg_popularity=("popularity","mean")

)

# %%
groupby_explit
# Out:
#           song_cont  avg_popularity
# explicit
# False          1393       59.230438
# True            533       61.427767

# %% [markdown]
# Duración óptima: ¿canciones cortas o largas son más vistas?

# %%
df["min_time"] = (df["duration_ms"] / (1000 * 60)).round(2)

# %%
bins=[0,2.5,3.5,4.5,df["min_time"].max()]
labels=["<2.5 min","2.5–3.5 min","3.5–4.5 min",">4.5 min"]
df["duration_bucket"]=pd.cut(df["min_time"],bins=bins,labels=labels)

# %%
df["duration_bucket"].value_counts()
# Out:
# duration_bucket
# 3.5–4.5 min    1050
# 2.5–3.5 min     609
# >4.5 min        249
# <2.5 min         18
# Name: count, dtype: int64

# %% [markdown]
# Popularidad por decada

# %%
df['decade'] =(df['year']//10)*10

# %%
groupby_decade= df.groupby("decade").agg(

    song_count=("song","count"),
    popularidad_log=("popularity",score_log)

)

# %%
groupby_decade
# Out:
#         song_count  popularidad_log
# decade
# 1990            39        29.741229
# 2000           904        25.319653
# 2010           980        16.083130
# 2020             3         3.935455

# %% [markdown]
# Top 3 de cada decada

# %%
top_por_decada = df.groupby('decade').apply(lambda x: x.nlargest(3, 'popularity')).reset_index(drop=True)
top_por_decada.sort_values("decade",ascending=True)
# Out:
# <ipython-input-297-04f7b62bd7ef>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_por_decada = df.groupby('decade').apply(lambda x: x.nlargest(3, 'popularity')).reset_index(drop=True)
#                artist                     song  duration_ms  explicit  year  \
# 0             Dr. Dre         The Next Episode       161506      True  1999
# 1             Dr. Dre         Forgot About Dre       222293      True  1999
# 2           blink-182     All The Small Things       167066     False  1999
# 3              Eminem               Without Me       290320      True  2002
# 4              Eminem      The Real Slim Shady       284200      True  2000
# 5              Eminem         'Till I Collapse       297786      True  2002
# 6   The Neighbourhood          Sweater Weather       240400     False  2013
# 7           Tom Odell             Another Love       244360      True  2013
# 8              WILLOW           Wait a Minute!       196520     False  2015
# 9                 NSG                  Options       240081      True  2020
# 10           t.A.T.u.  All The Things She Said       214440      True  2020
# 11         Will Smith                   Switch       197666     False  2020
#
#     popularity  danceability  energy  key  loudness  ...  acousticness  \
# 0           82         0.922   0.909   10    -2.429  ...       0.02810
# 1           79         0.924   0.740    8    -1.299  ...       0.08270
# 2           79         0.434   0.897    0    -4.918  ...       0.01030
# 3           87         0.908   0.669    7    -2.827  ...       0.00286
# 4           86         0.949   0.661    5    -4.244  ...       0.03020
# 5           85         0.548   0.847    1    -3.237  ...       0.06220
# 6           89         0.612   0.807   10    -2.810  ...       0.04950
# 7           88         0.445   0.537    4    -8.532  ...       0.69500
# 8           86         0.764   0.705    3    -5.279  ...       0.03710
# 9           57         0.836   0.621    1    -4.684  ...       0.38900
# 10          39         0.527   0.834    5    -5.767  ...       0.04110
# 11          34         0.873   0.900    5    -4.325  ...       0.01070
#
#     instrumentalness  liveness  valence    tempo                       genre  \
# 0           0.000000    0.0856    0.309   95.295                     hip hop
# 1           0.000000    0.1630    0.621  133.974                     hip hop
# 2           0.000000    0.6120    0.684  148.726                   rock, pop
# 3           0.000000    0.2370    0.662  112.238                     hip hop
# 4           0.000000    0.0454    0.760  104.504                     hip hop
# 5           0.000000    0.0816    0.100  171.447                     hip hop
# 6           0.017700    0.1010    0.398  124.053                   rock, pop
# 7           0.000017    0.0944    0.131  122.769                         pop
# 8           0.000019    0.0943    0.672  101.003  pop, R&B, Dance/Electronic
# 9           0.000092    0.1040    0.762  101.993  World/Traditional, hip hop
# 10          0.005990    0.1050    0.381  179.920                         pop
# 11          0.000502    0.5560    0.478  102.516                hip hop, pop
#
#                    genre_clean min_time duration_bucket  decade
# 0                      hip hop     2.69     2.5–3.5 min    1990
# 1                      hip hop     3.70     3.5–4.5 min    1990
# 2                    pop, rock     2.78     2.5–3.5 min    1990
# 3                      hip hop     4.84        >4.5 min    2000
# 4                      hip hop     4.74        >4.5 min    2000
# 5                      hip hop     4.96        >4.5 min    2000
# 6                    pop, rock     4.01     3.5–4.5 min    2010
# 7                          pop     4.07     3.5–4.5 min    2010
# 8   dance/electronic, pop, r&b     3.28     2.5–3.5 min    2010
# 9   hip hop, world/traditional     4.00     3.5–4.5 min    2020
# 10                         pop     3.57     3.5–4.5 min    2020
# 11                hip hop, pop     3.29     2.5–3.5 min    2020
#
# [12 rows x 22 columns]

# %% [markdown]
# **Popularidad de las commbinaciones de generos**

# %%
trend = (
    df.groupby(['decade','genre'])['popularity']
      .mean()
      .reset_index()
)
# Luego filtrar un género y graficar:
pop_trend = trend[trend['genre']=='pop']

# %%
trend
# Out:
#      decade                               genre  popularity
# 0      1990                    Dance/Electronic   56.000000
# 1      1990                         desconocido   71.000000
# 2      1990                             hip hop   76.666667
# 3      1990                        hip hop, pop   71.000000
# 4      1990                   hip hop, pop, R&B   59.250000
# ..      ...                                 ...         ...
# 102    2010         rock, pop, Dance/Electronic   46.166667
# 103    2010  rock, pop, metal, Dance/Electronic   76.000000
# 104    2020          World/Traditional, hip hop   57.000000
# 105    2020                        hip hop, pop   34.000000
# 106    2020                                 pop   39.000000
#
# [107 rows x 3 columns]

# %% [markdown]
# **Genero mas popular por decada**

# %%
pop_trend
# Out:
#      decade genre  popularity
# 5      1990   pop   62.000000
# 42     2000   pop   58.551724
# 85     2010   pop   59.524444
# 106    2020   pop   39.000000

# %%
df[df['genre_clean'] == 'set()']['genre']
# Out:
# Series([], Name: genre, dtype: object)

# %%
df.head()
# Out:
#               artist                  song  duration_ms  explicit  year  \
# 0  The Neighbourhood       Sweater Weather       240400     False  2013
# 1          Tom Odell          Another Love       244360      True  2013
# 2             Eminem            Without Me       290320      True  2002
# 3             WILLOW        Wait a Minute!       196520     False  2015
# 4      Billie Eilish  lovely (with Khalid)       200185     False  2018
#
#    popularity  danceability  energy  key  loudness  ...  acousticness  \
# 0          89         0.612   0.807   10    -2.810  ...       0.04950
# 1          88         0.445   0.537    4    -8.532  ...       0.69500
# 2          87         0.908   0.669    7    -2.827  ...       0.00286
# 3          86         0.764   0.705    3    -5.279  ...       0.03710
# 4          86         0.351   0.296    4   -10.109  ...       0.93400
#
#    instrumentalness  liveness  valence    tempo                       genre  \
# 0          0.017700    0.1010    0.398  124.053                   rock, pop
# 1          0.000017    0.0944    0.131  122.769                         pop
# 2          0.000000    0.2370    0.662  112.238                     hip hop
# 3          0.000019    0.0943    0.672  101.003  pop, R&B, Dance/Electronic
# 4          0.000000    0.0950    0.120  115.284       pop, Dance/Electronic
#
#                   genre_clean min_time duration_bucket  decade
# 0                   pop, rock     4.01     3.5–4.5 min    2010
# 1                         pop     4.07     3.5–4.5 min    2010
# 2                     hip hop     4.84        >4.5 min    2000
# 3  dance/electronic, pop, r&b     3.28     2.5–3.5 min    2010
# 4       dance/electronic, pop     3.34     2.5–3.5 min    2010
#
# [5 rows x 22 columns]
